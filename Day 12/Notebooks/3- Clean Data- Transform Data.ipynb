# %%
import os
import pandas as pd

# %%
cwd = os.getcwd() #to grab dirname of absolute path of (__file__)
BASE_DIR = os.path.dirname(cwd)
DATA_DIR = os.path.join(BASE_DIR, 'data')
CACHE_DIR = os.path.join(BASE_DIR, 'cache')
working_file= os.path.join(CACHE_DIR, 'movies-box-office-dataset.csv')
output_file= os.path.join(CACHE_DIR, 'movies-box-office-dataset_cleaned.csv')

# %%
df= pd.read_csv(working_file)

# %%
df.head(120)
# Out:
#      Rank                                      Release Group     Worldwide  \
# 0       1                                  Bad Boys for Life  $425,514,702
# 1       2                                 Sonic the Hedgehog  $306,766,470
# 2       3                                           Dolittle  $227,908,130
# 3       4  Birds of Prey: And the Fantabulous Emancipatio...  $201,858,461
# 4       5                                  The Invisible Man  $124,549,496
# ..    ...                                                ...           ...
# 115    84                                              After   $69,733,482
# 116    85                                               Exit   $69,501,772
# 117    86                                  Playing with Fire   $68,631,669
# 118    87                A Beautiful Day in the Neighborhood   $67,760,877
# 119    88                                                War   $67,179,155
#
#          Domestic      %       Foreign    %.1  filename  year
# 0    $204,417,855    48%  $221,096,847    52%  2020.csv  2020
# 1    $146,066,470  47.6%  $160,700,000  52.4%  2020.csv  2020
# 2     $77,047,065  33.8%  $150,861,065  66.2%  2020.csv  2020
# 3     $84,158,461  41.7%  $117,700,000  58.3%  2020.csv  2020
# 4     $64,914,050  52.1%   $59,635,446  47.9%  2020.csv  2020
# ..            ...    ...           ...    ...       ...   ...
# 115   $12,138,565  17.4%   $57,594,917  82.6%  2019.csv  2019
# 116      $470,699   0.7%   $69,031,073  99.3%  2019.csv  2019
# 117   $44,451,847  64.8%   $24,179,822  35.2%  2019.csv  2019
# 118   $61,704,055  91.1%    $6,056,822   8.9%  2019.csv  2019
# 119    $4,654,000   6.9%   $62,525,155  93.1%  2019.csv  2019
#
# [120 rows x 9 columns]

# %%
#to remember to set this column
df['Rank']= -1

# %%
df.head()
# Out:
#    Rank                                      Release Group     Worldwide  \
# 0    -1                                  Bad Boys for Life  $425,514,702
# 1    -1                                 Sonic the Hedgehog  $306,766,470
# 2    -1                                           Dolittle  $227,908,130
# 3    -1  Birds of Prey: And the Fantabulous Emancipatio...  $201,858,461
# 4    -1                                  The Invisible Man  $124,549,496
#
#        Domestic      %       Foreign    %.1  filename  year
# 0  $204,417,855    48%  $221,096,847    52%  2020.csv  2020
# 1  $146,066,470  47.6%  $160,700,000  52.4%  2020.csv  2020
# 2   $77,047,065  33.8%  $150,861,065  66.2%  2020.csv  2020
# 3   $84,158,461  41.7%  $117,700,000  58.3%  2020.csv  2020
# 4   $64,914,050  52.1%   $59,635,446  47.9%  2020.csv  2020

# %%
df['Domestic %'] = df['%']
df['Foreign %'] = df['%.1']
df.head()
# Out:
#    Rank                                      Release Group     Worldwide  \
# 0    -1                                  Bad Boys for Life  $425,514,702
# 1    -1                                 Sonic the Hedgehog  $306,766,470
# 2    -1                                           Dolittle  $227,908,130
# 3    -1  Birds of Prey: And the Fantabulous Emancipatio...  $201,858,461
# 4    -1                                  The Invisible Man  $124,549,496
#
#        Domestic      %       Foreign    %.1  filename  year Domestic %  \
# 0  $204,417,855    48%  $221,096,847    52%  2020.csv  2020        48%
# 1  $146,066,470  47.6%  $160,700,000  52.4%  2020.csv  2020      47.6%
# 2   $77,047,065  33.8%  $150,861,065  66.2%  2020.csv  2020      33.8%
# 3   $84,158,461  41.7%  $117,700,000  58.3%  2020.csv  2020      41.7%
# 4   $64,914,050  52.1%   $59,635,446  47.9%  2020.csv  2020      52.1%
#
#   Foreign %
# 0       52%
# 1     52.4%
# 2     66.2%
# 3     58.3%
# 4     47.9%

# %%
#df.drop(columns=['%', '%.1']) 1 way to write it or
#new_df= df.drop(['%', '%.1'], axis=1,inplace=True) or
df.drop(['%', '%.1'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Rank                                      Release Group     Worldwide  \
# 0    -1                                  Bad Boys for Life  $425,514,702
# 1    -1                                 Sonic the Hedgehog  $306,766,470
# 2    -1                                           Dolittle  $227,908,130
# 3    -1  Birds of Prey: And the Fantabulous Emancipatio...  $201,858,461
# 4    -1                                  The Invisible Man  $124,549,496
#
#        Domestic       Foreign  filename  year Domestic % Foreign %
# 0  $204,417,855  $221,096,847  2020.csv  2020        48%       52%
# 1  $146,066,470  $160,700,000  2020.csv  2020      47.6%     52.4%
# 2   $77,047,065  $150,861,065  2020.csv  2020      33.8%     66.2%
# 3   $84,158,461  $117,700,000  2020.csv  2020      41.7%     58.3%
# 4   $64,914,050   $59,635,446  2020.csv  2020      52.1%     47.9%

# %%
#an attempt at fropping th dollar sign ij worldwide column
df['Worldwide']= df['Worldwide'].replace('$', '').replace(',', '')

# %%
df.head()
# Out:
#    Rank                                      Release Group     Worldwide  \
# 0    -1                                  Bad Boys for Life  $425,514,702
# 1    -1                                 Sonic the Hedgehog  $306,766,470
# 2    -1                                           Dolittle  $227,908,130
# 3    -1  Birds of Prey: And the Fantabulous Emancipatio...  $201,858,461
# 4    -1                                  The Invisible Man  $124,549,496
#
#        Domestic       Foreign  filename  year Domestic % Foreign %
# 0  $204,417,855  $221,096,847  2020.csv  2020        48%       52%
# 1  $146,066,470  $160,700,000  2020.csv  2020      47.6%     52.4%
# 2   $77,047,065  $150,861,065  2020.csv  2020      33.8%     66.2%
# 3   $84,158,461  $117,700,000  2020.csv  2020      41.7%     58.3%
# 4   $64,914,050   $59,635,446  2020.csv  2020      52.1%     47.9%

# %%
#another attempt at dropping the dollar sign ij worldwide column
to_clean_cols = ['Worldwide', 'Domestic', 'Foreign']

def currency_str_to_int(current_val):
    currency_val = current_val.replace('$', '').replace(',', '')
    try:
        currency_val = int(currency_val)
    except:
        # Takes any row value with "-" and turns into 0
        currency_val = 0
    return currency_val


def clean_col(row):
    
    #row = Pandas Series
    #dataframe = collecrtion of pandas series
   
    #print(row)
    for col in to_clean_cols:
        current_val = row[col]
        row[col] = currency_str_to_int(current_val)
    return row
    #pass
df_cleaned = df.apply(clean_col, axis=1)
df_cleaned.head()
# Out:
#    Rank                                      Release Group  Worldwide  \
# 0    -1                                  Bad Boys for Life  425514702
# 1    -1                                 Sonic the Hedgehog  306766470
# 2    -1                                           Dolittle  227908130
# 3    -1  Birds of Prey: And the Fantabulous Emancipatio...  201858461
# 4    -1                                  The Invisible Man  124549496
#
#     Domestic    Foreign  filename  year Domestic % Foreign %
# 0  204417855  221096847  2020.csv  2020        48%       52%
# 1  146066470  160700000  2020.csv  2020      47.6%     52.4%
# 2   77047065  150861065  2020.csv  2020      33.8%     66.2%
# 3   84158461  117700000  2020.csv  2020      41.7%     58.3%
# 4   64914050   59635446  2020.csv  2020      52.1%     47.9%

# %%
df_cleaned.dtypes
# Out:
# Rank              int64
# Release Group    object
# Worldwide         int64
# Domestic          int64
# Foreign           int64
# filename         object
# year              int64
# Domestic %       object
# Foreign %        object
# dtype: object

# %%
df.dtypes
# Out:
# Rank              int64
# Release Group    object
# Worldwide        object
# Domestic         object
# Foreign          object
# filename         object
# year              int64
# Domestic %       object
# Foreign %        object
# dtype: object

# %%
df_cleaned.sort_values(by=['Worldwide'], inplace=True, ascending=False)
df_cleaned.head()
# Out:
#       Rank                               Release Group   Worldwide   Domestic  \
# 32      -1                           Avengers: Endgame  2797800564  858373000
# 2021    -1  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 717     -1                      Avengers: Infinity War  2048359754  678815482
# 2022    -1                              Jurassic World  1670400637  652270625
# 33      -1                               The Lion King  1656943394  543638043
#
#          Foreign  filename  year Domestic % Foreign %
# 32    1939427564  2019.csv  2019      30.7%     69.3%
# 2021  1131561399  2015.csv  2015      45.3%     54.7%
# 717   1369544272  2018.csv  2018      33.1%     66.9%
# 2022  1018130012  2015.csv  2015        39%       61%
# 33    1113305351  2019.csv  2019      32.8%     67.2%

# %%
df_cleaned.reset_index(inplace=True, drop=True)
df_cleaned.head()
# Out:
#    Rank                               Release Group   Worldwide   Domestic  \
# 0    -1                           Avengers: Endgame  2797800564  858373000
# 1    -1  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 2    -1                      Avengers: Infinity War  2048359754  678815482
# 3    -1                              Jurassic World  1670400637  652270625
# 4    -1                               The Lion King  1656943394  543638043
#
#       Foreign  filename  year Domestic % Foreign %
# 0  1939427564  2019.csv  2019      30.7%     69.3%
# 1  1131561399  2015.csv  2015      45.3%     54.7%
# 2  1369544272  2018.csv  2018      33.1%     66.9%
# 3  1018130012  2015.csv  2015        39%       61%
# 4  1113305351  2019.csv  2019      32.8%     67.2%

# %%
df_cleaned['Rank'] = df_cleaned.index + 1
df_cleaned.head()
# Out:
#    Rank                               Release Group   Worldwide   Domestic  \
# 0     1                           Avengers: Endgame  2797800564  858373000
# 1     2  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 2     3                      Avengers: Infinity War  2048359754  678815482
# 3     4                              Jurassic World  1670400637  652270625
# 4     5                               The Lion King  1656943394  543638043
#
#       Foreign  filename  year Domestic % Foreign %
# 0  1939427564  2019.csv  2019      30.7%     69.3%
# 1  1131561399  2015.csv  2015      45.3%     54.7%
# 2  1369544272  2018.csv  2018      33.1%     66.9%
# 3  1018130012  2015.csv  2015        39%       61%
# 4  1113305351  2019.csv  2019      32.8%     67.2%

# %%
df_cleaned ['Domestic %'] = df_cleaned ['Domestic'] / df_cleaned['Worldwide']
df_cleaned ['Foreign %'] = df_cleaned ['Foreign'] / df_cleaned['Worldwide']

# %%
df_cleaned.head()
# Out:
#    Rank                               Release Group   Worldwide   Domestic  \
# 0     1                           Avengers: Endgame  2797800564  858373000
# 1     2  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 2     3                      Avengers: Infinity War  2048359754  678815482
# 3     4                              Jurassic World  1670400637  652270625
# 4     5                               The Lion King  1656943394  543638043
#
#       Foreign  filename  year  Domestic %  Foreign %
# 0  1939427564  2019.csv  2019    0.306803   0.693197
# 1  1131561399  2015.csv  2015    0.452882   0.547118
# 2  1369544272  2018.csv  2018    0.331395   0.668605
# 3  1018130012  2015.csv  2015    0.390488   0.609512
# 4  1113305351  2019.csv  2019    0.328097   0.671903

# %%
df_cleaned.dtypes
# Out:
# Rank               int64
# Release Group     object
# Worldwide          int64
# Domestic           int64
# Foreign            int64
# filename          object
# year               int64
# Domestic %       float64
# Foreign %        float64
# dtype: object

# %%
df_cleaned.to_csv(output_file, index= False)
