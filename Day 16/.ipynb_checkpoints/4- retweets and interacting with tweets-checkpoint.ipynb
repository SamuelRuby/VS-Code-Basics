# %%
import tweepy
import webbrowser
import time
import pandas as pd

# %%
#to read ini file, where my credentials are stored
import configparser
config = configparser.ConfigParser()
config.read('/Users/ruby/Desktop/VS-Code-Basics/credentials.ini')
# Out:
# ['/Users/ruby/Desktop/VS-Code-Basics/credentials.ini']

# %%
#print(config['TWITTER_CREDENTIALS']['ACCESS_TOKEN'])

#consumer_key = config['TWITTER_CREDENTIALS']['CONSUMER_API_KEY']

cred = config["TWITTER_CREDENTIALS"]
consumer_key = cred["CONSUMER_API_KEY"]
consumer_secret = cred["CONSUMER_API_SECRET"]
access_token = cred["ACCESS_TOKEN"]
access_secret = cred["ACCESS_TOKEN_SECRET"]

# %%
callback_url = 'oob' #url/callback
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_url) #oauth is a standerdized way of an authentication that allows the user to login in to the service you are trying to log into
redirect_url = auth.get_authorization_url()
webbrowser.open(redirect_url)
user_pin_input = input('What is the pin value? ')
auth.get_access_token(user_pin_input)
# Out:
# What is the pin value? YD0qynLe1P99u1rlJsUnYQUe9rhWv8xl
# ('3028005622-TWInusX39SJOXscJ9wtsawKDl3Na5YfV1XI3o9n',
#  'CPeH5d30znW1RBDtx85iDDcWcEDRxKj1fHcz5BB2lOMjw')

# %%
api = tweepy.API(auth)

# %%
me = api.verify_credentials()
print (me.screen_name)
# Out:
# keghannruby

# %%
user = api.get_user(screen_name ="Mochievous", include_entities=False)
user_timeline = user.timeline()
user_timeline_status_obj= user_timeline[0]
status_obj_id = user_timeline_status_obj.id

#print (status_obj_id)
status_obj_screen_name = user_timeline_status_obj.user.screen_name
status_obj_url = f"https://twitter.com/{status_obj_screen_name}/status/{status_obj_id}"
print(status_obj_url)
# Out:
# https://twitter.com/Mochievous/status/1534865191938232322

# %%
status_obj = api.get_status('1534837432683835394')
status_obj.text
# Out:
# 'Big things start small. Never forget that. \n\nYour small actions create a ripple effect. Don’t ever think taking act… https://t.co/yz5iQXtacq'

# %%
api.retweet(status_obj_id)
# Out:
# Status(_api=<tweepy.api.API object at 0x7fd9860ce040>, _json={'created_at': 'Thu Jun 09 20:56:19 +0000 2022', 'id': 1535002878036828174, 'id_str': '1535002878036828174', 'text': 'RT @Mochievous: Set a reminder for my upcoming Space! \n#PeterObi2023 \nhttps://t.co/dQ7iF0lfnC https://t.co/SAmQBMyZtv', 'truncated': False, 'entities': {'hashtags': [{'text': 'PeterObi2023', 'indices': [55, 68]}], 'symbols': [], 'user_mentions': [{'screen_name': 'Mochievous', 'name': 'Moe', 'id': 72853440, 'id_str': '72853440', 'indices': [3, 14]}], 'urls': [{'url': 'https://t.co/dQ7iF0lfnC', 'expanded_url': 'https://twitter.com/i/spaces/1MnxnkEDNpBKO', 'display_url': 'twitter.com/i/spaces/1Mnxn…', 'indices': [70, 93]}], 'media': [{'id': 1534645356721541125, 'id_str': '1534645356721541125', 'indices': [94, 117], 'media_url': 'http://pbs.twimg.com/media/FUwn0i-XEAUxjb7.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FUwn0i-XEAUxjb7.jpg', 'url': 'https://t.co/SAmQBMyZtv', 'display_url': 'pic.twitter.co
# ...

# %%
api.create_favorite(status_obj_id) #to like a tweet
# Out:
# Status(_api=<tweepy.api.API object at 0x7fd9860ce040>, _json={'created_at': 'Thu Jun 09 11:49:12 +0000 2022', 'id': 1534865191938232322, 'id_str': '1534865191938232322', 'text': 'RT @Mochievous: Set a reminder for my upcoming Space! \n#PeterObi2023 \nhttps://t.co/dQ7iF0lfnC https://t.co/SAmQBMyZtv', 'truncated': False, 'entities': {'hashtags': [{'text': 'PeterObi2023', 'indices': [55, 68]}], 'symbols': [], 'user_mentions': [{'screen_name': 'Mochievous', 'name': 'Moe', 'id': 72853440, 'id_str': '72853440', 'indices': [3, 14]}], 'urls': [{'url': 'https://t.co/dQ7iF0lfnC', 'expanded_url': 'https://twitter.com/i/spaces/1MnxnkEDNpBKO', 'display_url': 'twitter.com/i/spaces/1Mnxn…', 'indices': [70, 93]}], 'media': [{'id': 1534645356721541125, 'id_str': '1534645356721541125', 'indices': [94, 117], 'media_url': 'http://pbs.twimg.com/media/FUwn0i-XEAUxjb7.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FUwn0i-XEAUxjb7.jpg', 'url': 'https://t.co/SAmQBMyZtv', 'display_url': 'pic.twitter.co
# ...

# %%
api.destroy_favorite(status_obj_id)
# Out:
# Status(_api=<tweepy.api.API object at 0x7fd9860ce040>, _json={'created_at': 'Thu Jun 09 11:49:12 +0000 2022', 'id': 1534865191938232322, 'id_str': '1534865191938232322', 'text': 'RT @Mochievous: Set a reminder for my upcoming Space! \n#PeterObi2023 \nhttps://t.co/dQ7iF0lfnC https://t.co/SAmQBMyZtv', 'truncated': False, 'entities': {'hashtags': [{'text': 'PeterObi2023', 'indices': [55, 68]}], 'symbols': [], 'user_mentions': [{'screen_name': 'Mochievous', 'name': 'Moe', 'id': 72853440, 'id_str': '72853440', 'indices': [3, 14]}], 'urls': [{'url': 'https://t.co/dQ7iF0lfnC', 'expanded_url': 'https://twitter.com/i/spaces/1MnxnkEDNpBKO', 'display_url': 'twitter.com/i/spaces/1Mnxn…', 'indices': [70, 93]}], 'media': [{'id': 1534645356721541125, 'id_str': '1534645356721541125', 'indices': [94, 117], 'media_url': 'http://pbs.twimg.com/media/FUwn0i-XEAUxjb7.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FUwn0i-XEAUxjb7.jpg', 'url': 'https://t.co/SAmQBMyZtv', 'display_url': 'pic.twitter.co
# ...

# %%
og_tweet = api.get_status('1534837432683835394')
#print(og_tweet.user.screen_name, og_tweet.id)
#tweet = "This is so true!"
my_reply = api.update_status(f"@{og_tweet.user.screen_name} This is so true!", og_tweet.id)

#my_reply = api.update_status(f"@{og_tweet.user.screen_name} Wow this cool!", og_tweet.id)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 4>()
#       1 og_tweet = api.get_status('1534837432683835394')
#       2 #print(og_tweet.user.screen_name, og_tweet.id)
#       3 #tweet = "This is so true!"
# ----> 4 my_reply = api.update_status(f"@{og_tweet.user.screen_name} This is so true!", og_tweet.id)
#
# File ~/.local/share/virtualenvs/VS-Code-Basics-oL_Sh4cK/lib/python3.9/site-packages/tweepy/api.py:46, in payload.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      44 kwargs['payload_list'] = payload_list
#      45 kwargs['payload_type'] = payload_type
# ---> 46 return method(*args, **kwargs)
#
# TypeError: update_status() takes 2 positional arguments but 3 were given

# %%
@('Mochievous', 1534837432683835394) This is so true!

# %%
print(my_reply.id, my_reply.user.screen_name)
# Out:
# 1535004450905022476 keghannruby
